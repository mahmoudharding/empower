# %% [markdown]
# # Say my name
#
# ## Data Wrangling

# %% [markdown]
# Import `datascience`, `numpy`, and `matplotlib.pyplot`

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# # Wild Ending
#
# ## Simulation
#
# Go to the 1:45 mark in the video.

# %%
from IPython.display import YouTubeVideo

# YouTube video ID
video_id = 'fsgScuAH4NI'

# Embed the YouTube video
YouTubeVideo(video_id, width = 800, height = 400)

# %% [markdown]
# # A | B Testing
#
# ## Comparing Two Samples
#
# - [Smoking and birthweight](https://inferentialthinking.com/chapters/12/1/AB_Testing.html?highlight=birthweight)
#
# - [Maternal Smoking and Infant Weight](https://www.stat.berkeley.edu/~statlabs/papers/sample.pdf)
#
# - [AB_Testing.ipynb](https://github.com/data-8/textbook/blob/main/chapters/12/1/AB_Testing.ipynb)
